# %% [markdown]
# **Week-3:** Design Deep forward Neural Network for image classification
# - Design and implement an Image classification model to classify a dataset of images using Deep
#    Feed Forward NN.
# - Use the MNIST datasets.
# - Record the accuracy corresponding to the number of epochs 5, 50, 100.
# - Repeat for CIFAR10 datasets. Note down the changes made and the accuracies obtained.

# %% [markdown]
# MNIST Dataset: https://www.kaggle.com/datasets/hojjatk/mnist-dataset

# %% [markdown]
# CIFAR10 and CIFAR100 Datasets(University of Toronto): https://www.cs.toronto.edu/~kriz/cifar.html

# %% [markdown]
# CIFAR10 Dataset (Kaggle): https://www.kaggle.com/c/cifar-10/

# %% [markdown]
# Fashion MNIST Dataset(Kaggle): https://www.kaggle.com/datasets/zalando-research/fashionmnist

# %%
#load required packages
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras import Input
from keras.layers import Dense
import pandas as pd
import numpy as np
import sklearn
from sklearn.metrics import classification_report
import matplotlib
import matplotlib.pyplot as plt
# Load digits data
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
# Print shapes
print("Shape of X_train: ", X_train.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of y_test: ", y_test.shape)
# Display images of the first 10 digits in the training set and their true lables
fig, axs = plt.subplots(2, 5, sharey=False, tight_layout=True, figsize=(12,6),
facecolor='white')
n=0
for i in range(0,2):
for j in range(0,5):
axs[i,j].matshow(X_train[n])
axs[i,j].set(title=y_train[n])
n=n+1
plt.show()
# Reshape and normalize (divide by 255) input data
X_train = X_train.reshape(60000, 784).astype("float32") / 255
X_test = X_test.reshape(10000, 784).astype("float32") / 255
# Print shapes
print("New shape of X_train: ", X_train.shape)
print("New shape of X_test: ", X_test.shape)
#Design the Deep FF Neural Network architecture
model = Sequential(name="DFF-Model") # Model
model.add(Input(shape=(784,), name='Input-Layer')) # Input Layer - need to specify the shape of inputs
model.add(Dense(128, activation='relu', name='Hidden-Layer-1',
kernel_initializer='HeNormal'))
model.add(Dense(64, activation='relu', name='Hidden-Layer-2',
kernel_initializer='HeNormal'))
model.add(Dense(32, activation='relu', name='Hidden-Layer-3',
kernel_initializer='HeNormal'))
model.add(Dense(10, activation='softmax', name='Output-Layer'))
#Compile keras model
model.compile(optimizer='adam', loss='SparseCategoricalCrossentropy',
metrics=['Accuracy'], loss_weights=None, weighted_metrics=None, run_eagerly=None,
steps_per_execution=None)
#Fit keras model on the dataset
model.fit(X_train, y_train, batch_size=10, epochs=5, verbose='auto', callbacks=None,
validation_split=0.2, shuffle=True, class_weight=None, sample_weight=None,
initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for
resuming a previous training run).

steps_per_epoch=None, validation_steps=None, validation_batch_size=None,
validation_freq=5, max_queue_size=10, workers=1, use_multiprocessing=False,)
# apply the trained model to make predictions
# Predict class labels on training data
pred_labels_tr = np.array(tf.math.argmax(model.predict(X_train),axis=1))
# Predict class labels on a test data
pred_labels_te = np.array(tf.math.argmax(model.predict(X_test),axis=1))

#Model Performance Summary
print("")
print(' Model Summary
model.summary()
print("")

')

# Printing the parameters:Deep Feed Forward Neural Network contains more than 100K
#print(' Weights and Biases
#for layer in model_d1.layers:

')

#print("Layer: ", layer.name) # print layer name
#print(" --Kernels (Weights): ", layer.get_weights()[0]) # kernels (weights)
#print(" --Biases: ", layer.get_weights()[1]) # biases
print("")
print('---------- Evaluation on Training Data -----------')
print(classification_report(y_train, pred_labels_tr))
print("")
print('---------- Evaluation on Test Data -----------')
print(classification_report(y_test, pred_labels_te))
print("")
# Out:
#   File "<ipython-input-2-3512b1239d70>", line 56
#     steps_per_epoch=None, validation_steps=None, validation_batch_size=None,validation_freq=5, max_queue_size=10, workers=1, use_multiprocessing=False,)
#                                                                                                                                                        ^
# SyntaxError: unmatched ')'

# %% [markdown]
# To-Do:
# Use the MNIST datasets.
#
# Use the CIFAR10 datasets.
#
# *Record the accuracy corresponding to the number of epochs 5, 50, 100.
#
# *Repeat for CIFAR10 datasets. Note down the changes made and the accuracies obtained.
#
# *Use the Fashion MNIST Dataset
#
# *Perform and Plot the Comparative Analysis.

# %%
# Load required packages
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras import Input
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report

# Load digits data
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# Print shapes
print("Shape of X_train: ", X_train.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of y_test: ", y_test.shape)

# Display images of the first 10 digits in the training set and their true labels
fig, axs = plt.subplots(2, 5, sharey=False, tight_layout=True, figsize=(12, 6),
                         facecolor='white')
n = 0
for i in range(2):
    for j in range(5):
        axs[i, j].matshow(X_train[n])
        axs[i, j].set(title=y_train[n])
        axs[i, j].axis('off')  # Hide axes for clarity
        n += 1
plt.show()

# Reshape and normalize (divide by 255) input data
X_train = X_train.reshape(60000, 784).astype("float32") / 255
X_test = X_test.reshape(10000, 784).astype("float32") / 255

# Print new shapes
print("New shape of X_train: ", X_train.shape)
print("New shape of X_test: ", X_test.shape)

# Design the Deep Feedforward Neural Network (DFF) architecture
model = Sequential(name="DFF-Model")  # Model
model.add(Input(shape=(784,), name='Input-Layer'))  # Input Layer
model.add(Dense(128, activation='relu', name='Hidden-Layer-1', kernel_initializer='HeNormal'))
model.add(Dense(64, activation='relu', name='Hidden-Layer-2', kernel_initializer='HeNormal'))
model.add(Dense(32, activation='relu', name='Hidden-Layer-3', kernel_initializer='HeNormal'))
model.add(Dense(10, activation='softmax', name='Output-Layer'))  # Output Layer

# Compile the Keras model
model.compile(optimizer='adam', loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# Fit the Keras model on the dataset
model.fit(X_train, y_train, batch_size=10, epochs=5, verbose=1, validation_split=0.2, shuffle=True)

# Apply the trained model to make predictions
# Predict class labels on training data
pred_labels_tr = np.array(tf.math.argmax(model.predict(X_train), axis=1))

# Predict class labels on test data
pred_labels_te = np.array(tf.math.argmax(model.predict(X_test), axis=1))

# Model Performance Summary
print("\nModel Summary:")
model.summary()

# Evaluation on Training Data
print("\n---------- Evaluation on Training Data -----------")
print(classification_report(y_train, pred_labels_tr))

# Evaluation on Test Data
print("\n---------- Evaluation on Test Data -----------")
print(classification_report(y_test, pred_labels_te))
# Out:
# Shape of X_train:  (60000, 28, 28)
# Shape of y_train:  (60000,)
# Shape of X_test:  (10000, 28, 28)
# Shape of y_test:  (10000,)
# New shape of X_train:  (60000, 784)
# New shape of X_test:  (10000, 784)
# Epoch 1/5
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 25s 5ms/step - accuracy: 0.8714 - loss: 0.4119 - val_accuracy: 0.9563 - val_loss: 0.1398
# Epoch 2/5
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 23s 5ms/step - accuracy: 0.9613 - loss: 0.1207 - val_accuracy: 0.9685 - val_loss: 0.1109
# Epoch 3/5
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.9754 - loss: 0.0816 - val_accuracy: 0.9703 - val_loss: 0.1048
# Epoch 4/5
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.9790 - loss: 0.0643 - val_accuracy: 0.9734 - val_loss: 0.0995
# Epoch 5/5
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 23s 5ms/step - accuracy: 0.9845 - loss: 0.0511 - val_accuracy: 0.9682 - val_loss: 0.1193
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# Model Summary:
# Model: "DFF-Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden-Layer-1 (Dense)          │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-3 (Dense)          │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output-Layer (Dense)            │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 333,440 (1.27 MB)
#  Trainable params: 111,146 (434.16 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 222,294 (868.34 KB)
# ---------- Evaluation on Training Data -----------
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      5923
#            1       0.99      0.99      0.99      6742
#            2       0.99      0.98      0.98      5958
#            3       0.98      0.98      0.98      6131
#            4       1.00      0.97      0.98      5842
#            5       0.93      0.99      0.96      5421
#            6       1.00      0.94      0.97      5918
#            7       0.98      0.99      0.98      6265
#            8       0.98      0.98      0.98      5851
#            9       0.98      0.99      0.98      5949
#
#     accuracy                           0.98     60000
#    macro avg       0.98      0.98      0.98     60000
# weighted avg       0.98      0.98      0.98     60000
#
#
# ---------- Evaluation on Test Data -----------
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       980
#            1       0.98      0.99      0.99      1135
#            2       0.97      0.96      0.97      1032
#            3       0.96      0.98      0.97      1010
#            4       0.99      0.95      0.97       982
#            5       0.91      0.98      0.94       892
#            6       0.99      0.92      0.95       958
#            7       0.96      0.98      0.97      1028
#            8       0.97      0.96      0.96       974
#            9       0.96      0.97      0.97      1009
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000

# %%
# Load required packages
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras import Input
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report

# Load digits data
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# Print shapes
print("Shape of X_train: ", X_train.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of y_test: ", y_test.shape)

# Display images of the first 10 digits in the training set and their true labels
fig, axs = plt.subplots(2, 5, sharey=False, tight_layout=True, figsize=(12, 6),
                         facecolor='white')
n = 0
for i in range(2):
    for j in range(5):
        axs[i, j].matshow(X_train[n])
        axs[i, j].set(title=y_train[n])
        axs[i, j].axis('off')  # Hide axes for clarity
        n += 1
plt.show()

# Reshape and normalize (divide by 255) input data
X_train = X_train.reshape(60000, 784).astype("float32") / 255
X_test = X_test.reshape(10000, 784).astype("float32") / 255

# Print new shapes
print("New shape of X_train: ", X_train.shape)
print("New shape of X_test: ", X_test.shape)

# Design the Deep Feedforward Neural Network (DFF) architecture
model = Sequential(name="DFF-Model")  # Model
model.add(Input(shape=(784,), name='Input-Layer'))  # Input Layer
model.add(Dense(128, activation='relu', name='Hidden-Layer-1', kernel_initializer='HeNormal'))
model.add(Dense(64, activation='relu', name='Hidden-Layer-2', kernel_initializer='HeNormal'))
model.add(Dense(32, activation='relu', name='Hidden-Layer-3', kernel_initializer='HeNormal'))
model.add(Dense(10, activation='softmax', name='Output-Layer'))  # Output Layer

# Compile the Keras model
model.compile(optimizer='adam', loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# Fit the Keras model on the dataset
model.fit(X_train, y_train, batch_size=10, epochs=10, verbose=1, validation_split=0.2, shuffle=True)

# Apply the trained model to make predictions
# Predict class labels on training data
pred_labels_tr = np.array(tf.math.argmax(model.predict(X_train), axis=1))

# Predict class labels on test data
pred_labels_te = np.array(tf.math.argmax(model.predict(X_test), axis=1))

# Model Performance Summary
print("\nModel Summary:")
model.summary()

# Evaluation on Training Data
print("\n---------- Evaluation on Training Data -----------")
print(classification_report(y_train, pred_labels_tr))

# Evaluation on Test Data
print("\n---------- Evaluation on Test Data -----------")
print(classification_report(y_test, pred_labels_te))
# Out:
# Shape of X_train:  (60000, 28, 28)
# Shape of y_train:  (60000,)
# Shape of X_test:  (10000, 28, 28)
# Shape of y_test:  (10000,)
# New shape of X_train:  (60000, 784)
# New shape of X_test:  (10000, 784)
# Epoch 1/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - accuracy: 0.8735 - loss: 0.4140 - val_accuracy: 0.9595 - val_loss: 0.1374
# Epoch 2/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 25s 5ms/step - accuracy: 0.9636 - loss: 0.1191 - val_accuracy: 0.9589 - val_loss: 0.1353
# Epoch 3/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 25s 5ms/step - accuracy: 0.9731 - loss: 0.0850 - val_accuracy: 0.9659 - val_loss: 0.1145
# Epoch 4/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.9798 - loss: 0.0649 - val_accuracy: 0.9728 - val_loss: 0.0936
# Epoch 5/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.9848 - loss: 0.0472 - val_accuracy: 0.9725 - val_loss: 0.1071
# Epoch 6/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.9867 - loss: 0.0413 - val_accuracy: 0.9747 - val_loss: 0.1029
# Epoch 7/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9873 - loss: 0.0365 - val_accuracy: 0.9715 - val_loss: 0.1111
# Epoch 8/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 37s 5ms/step - accuracy: 0.9905 - loss: 0.0312 - val_accuracy: 0.9732 - val_loss: 0.1177
# Epoch 9/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 26s 5ms/step - accuracy: 0.9903 - loss: 0.0283 - val_accuracy: 0.9710 - val_loss: 0.1448
# Epoch 10/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 38s 5ms/step - accuracy: 0.9912 - loss: 0.0277 - val_accuracy: 0.9726 - val_loss: 0.1257
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# Model Summary:
# Model: "DFF-Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden-Layer-1 (Dense)          │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-3 (Dense)          │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output-Layer (Dense)            │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 333,440 (1.27 MB)
#  Trainable params: 111,146 (434.16 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 222,294 (868.34 KB)
# ---------- Evaluation on Training Data -----------
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      5923
#            1       0.99      0.99      0.99      6742
#            2       0.99      0.99      0.99      5958
#            3       0.96      0.99      0.98      6131
#            4       1.00      0.98      0.99      5842
#            5       0.98      0.99      0.98      5421
#            6       1.00      0.99      0.99      5918
#            7       0.99      0.99      0.99      6265
#            8       0.99      0.96      0.98      5851
#            9       0.98      0.99      0.98      5949
#
#     accuracy                           0.99     60000
#    macro avg       0.99      0.99      0.99     60000
# weighted avg       0.99      0.99      0.99     60000
#
#
# ---------- Evaluation on Test Data -----------
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.97      0.97      0.97      1032
#            3       0.91      0.98      0.95      1010
#            4       0.99      0.96      0.97       982
#            5       0.96      0.98      0.97       892
#            6       0.99      0.98      0.98       958
#            7       0.98      0.97      0.97      1028
#            8       0.98      0.92      0.95       974
#            9       0.95      0.98      0.97      1009
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000

# %%
# Load required packages
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras import Input
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report

# Load digits data
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# Print shapes
print("Shape of X_train: ", X_train.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of y_test: ", y_test.shape)

# Display images of the first 10 digits in the training set and their true labels
fig, axs = plt.subplots(2, 5, sharey=False, tight_layout=True, figsize=(12, 6),
                         facecolor='white')
n = 0
for i in range(2):
    for j in range(5):
        axs[i, j].matshow(X_train[n])
        axs[i, j].set(title=y_train[n])
        axs[i, j].axis('off')  # Hide axes for clarity
        n += 1
plt.show()

# Reshape and normalize (divide by 255) input data
X_train = X_train.reshape(60000, 784).astype("float32") / 255
X_test = X_test.reshape(10000, 784).astype("float32") / 255

# Print new shapes
print("New shape of X_train: ", X_train.shape)
print("New shape of X_test: ", X_test.shape)

# Design the Deep Feedforward Neural Network (DFF) architecture
model = Sequential(name="DFF-Model")  # Model
model.add(Input(shape=(784,), name='Input-Layer'))  # Input Layer
model.add(Dense(128, activation='relu', name='Hidden-Layer-1', kernel_initializer='HeNormal'))
model.add(Dense(64, activation='relu', name='Hidden-Layer-2', kernel_initializer='HeNormal'))
model.add(Dense(32, activation='relu', name='Hidden-Layer-3', kernel_initializer='HeNormal'))
model.add(Dense(10, activation='softmax', name='Output-Layer'))  # Output Layer

# Compile the Keras model
model.compile(optimizer='adam', loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# Fit the Keras model on the dataset
model.fit(X_train, y_train, batch_size=10, epochs=15, verbose=1, validation_split=0.2, shuffle=True)

# Apply the trained model to make predictions
# Predict class labels on training data
pred_labels_tr = np.array(tf.math.argmax(model.predict(X_train), axis=1))

# Predict class labels on test data
pred_labels_te = np.array(tf.math.argmax(model.predict(X_test), axis=1))

# Model Performance Summary
print("\nModel Summary:")
model.summary()

# Evaluation on Training Data
print("\n---------- Evaluation on Training Data -----------")
print(classification_report(y_train, pred_labels_tr))

# Evaluation on Test Data
print("\n---------- Evaluation on Test Data -----------")
print(classification_report(y_test, pred_labels_te))
# Out:
# Shape of X_train:  (60000, 28, 28)
# Shape of y_train:  (60000,)
# Shape of X_test:  (10000, 28, 28)
# Shape of y_test:  (10000,)
# New shape of X_train:  (60000, 784)
# New shape of X_test:  (10000, 784)
# Epoch 1/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 25s 5ms/step - accuracy: 0.8741 - loss: 0.4093 - val_accuracy: 0.9438 - val_loss: 0.1874
# Epoch 2/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.9640 - loss: 0.1197 - val_accuracy: 0.9674 - val_loss: 0.1130
# Epoch 3/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.9747 - loss: 0.0811 - val_accuracy: 0.9679 - val_loss: 0.1166
# Epoch 4/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.9811 - loss: 0.0612 - val_accuracy: 0.9715 - val_loss: 0.1081
# Epoch 5/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 43s 5ms/step - accuracy: 0.9843 - loss: 0.0492 - val_accuracy: 0.9693 - val_loss: 0.1156
# Epoch 6/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 23s 5ms/step - accuracy: 0.9868 - loss: 0.0426 - val_accuracy: 0.9728 - val_loss: 0.1089
# Epoch 7/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 23s 5ms/step - accuracy: 0.9882 - loss: 0.0382 - val_accuracy: 0.9718 - val_loss: 0.1190
# Epoch 8/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.9905 - loss: 0.0319 - val_accuracy: 0.9764 - val_loss: 0.0975
# Epoch 9/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 25s 5ms/step - accuracy: 0.9918 - loss: 0.0281 - val_accuracy: 0.9688 - val_loss: 0.1392
# Epoch 10/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 23s 5ms/step - accuracy: 0.9918 - loss: 0.0259 - val_accuracy: 0.9751 - val_loss: 0.1120
# Epoch 11/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.9938 - loss: 0.0197 - val_accuracy: 0.9704 - val_loss: 0.1426
# Epoch 12/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.9937 - loss: 0.0215 - val_accuracy: 0.9761 - val_loss: 0.1188
# Epoch 13/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 23s 5ms/step - accuracy: 0.9939 - loss: 0.0202 - val_accuracy: 0.9730 - val_loss: 0.1415
# Epoch 14/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.9939 - loss: 0.0195 - val_accuracy: 0.9777 - val_loss: 0.1201
# Epoch 15/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.9962 - loss: 0.0126 - val_accuracy: 0.9762 - val_loss: 0.1249
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# Model Summary:
# Model: "DFF-Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden-Layer-1 (Dense)          │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-3 (Dense)          │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output-Layer (Dense)            │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 333,440 (1.27 MB)
#  Trainable params: 111,146 (434.16 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 222,294 (868.34 KB)
# ---------- Evaluation on Training Data -----------
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      5923
#            1       0.99      1.00      1.00      6742
#            2       0.99      1.00      0.99      5958
#            3       0.99      0.99      0.99      6131
#            4       0.99      1.00      0.99      5842
#            5       0.99      0.99      0.99      5421
#            6       1.00      0.99      1.00      5918
#            7       0.99      0.99      0.99      6265
#            8       0.99      0.99      0.99      5851
#            9       0.99      0.99      0.99      5949
#
#     accuracy                           0.99     60000
#    macro avg       0.99      0.99      0.99     60000
# weighted avg       0.99      0.99      0.99     60000
#
#
# ---------- Evaluation on Test Data -----------
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.96      0.98      0.97      1032
#            3       0.98      0.98      0.98      1010
#            4       0.97      0.99      0.98       982
#            5       0.97      0.97      0.97       892
#            6       0.99      0.98      0.98       958
#            7       0.98      0.97      0.98      1028
#            8       0.98      0.95      0.97       974
#            9       0.98      0.97      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
# Load required packages
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras import Input
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report

# Load digits data
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# Print shapes
print("Shape of X_train: ", X_train.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of y_test: ", y_test.shape)

# Display images of the first 10 digits in the training set and their true labels
fig, axs = plt.subplots(2, 5, sharey=False, tight_layout=True, figsize=(12, 6),
                         facecolor='white')
n = 0
for i in range(2):
    for j in range(5):
        axs[i, j].matshow(X_train[n])
        axs[i, j].set(title=y_train[n])
        axs[i, j].axis('off')  # Hide axes for clarity
        n += 1
plt.show()

# Reshape and normalize (divide by 255) input data
X_train = X_train.reshape(60000, 784).astype("float32") / 255
X_test = X_test.reshape(10000, 784).astype("float32") / 255

# Print new shapes
print("New shape of X_train: ", X_train.shape)
print("New shape of X_test: ", X_test.shape)

# Design the Deep Feedforward Neural Network (DFF) architecture
model = Sequential(name="DFF-Model")
model.add(Input(shape=(784,), name='Input-Layer'))
model.add(Dense(128, activation='relu', name='Hidden-Layer-1', kernel_initializer='HeNormal'))
model.add(Dense(64, activation='relu', name='Hidden-Layer-2', kernel_initializer='HeNormal'))
model.add(Dense(32, activation='relu', name='Hidden-Layer-3', kernel_initializer='HeNormal'))
model.add(Dense(10, activation='softmax', name='Output-Layer'))

# Compile the model
model.compile(optimizer='adam', loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# Fit the model
model.fit(X_train, y_train, batch_size=10, epochs=1, verbose=1, validation_split=0.2, shuffle=True)

# Predict class labels
pred_labels_tr = np.array(tf.math.argmax(model.predict(X_train), axis=1))
pred_labels_te = np.array(tf.math.argmax(model.predict(X_test), axis=1))

# Model Summary
print("\nModel Summary:")
model.summary()

# Evaluation Reports
print("\n---------- Evaluation on Training Data -----------")
report_train = classification_report(y_train, pred_labels_tr, output_dict=True)
print(classification_report(y_train, pred_labels_tr))

print("\n---------- Evaluation on Test Data -----------")
report_test = classification_report(y_test, pred_labels_te, output_dict=True)
print(classification_report(y_test, pred_labels_te))

# Comparative Analysis Plot
df_train = pd.DataFrame(report_train).transpose()
df_test = pd.DataFrame(report_test).transpose()

# Select metrics for macro average
metrics = ['precision', 'recall', 'f1-score']
train_scores = df_train.loc['macro avg', metrics]
test_scores = df_test.loc['macro avg', metrics]

# Plot comparison
x = np.arange(len(metrics))  # label locations
width = 0.35  # bar width

fig, ax = plt.subplots(figsize=(8, 6))
rects1 = ax.bar(x - width/2, train_scores, width, label='Training', color='skyblue')
rects2 = ax.bar(x + width/2, test_scores, width, label='Testing', color='salmon')

ax.set_ylabel('Scores')
ax.set_title('Macro Average Performance Comparison')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.set_ylim(0, 1.1)
ax.legend()

# Add value labels
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(rect.get_x() + rect.get_width()/2, height),
                    xytext=(0, 3),
                    textcoords='offset points',
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Print Accuracy separately
print(f"\nTraining Accuracy: {report_train['accuracy']:.4f}")
print(f"Testing Accuracy: {report_test['accuracy']:.4f}")
# Out:
# Shape of X_train:  (60000, 28, 28)
# Shape of y_train:  (60000,)
# Shape of X_test:  (10000, 28, 28)
# Shape of y_test:  (10000,)
# New shape of X_train:  (60000, 784)
# New shape of X_test:  (10000, 784)
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 27s 5ms/step - accuracy: 0.8712 - loss: 0.4103 - val_accuracy: 0.9619 - val_loss: 0.1268
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# Model Summary:
# Model: "DFF-Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden-Layer-1 (Dense)          │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-3 (Dense)          │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output-Layer (Dense)            │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 333,440 (1.27 MB)
#  Trainable params: 111,146 (434.16 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 222,294 (868.34 KB)
# ---------- Evaluation on Training Data -----------
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      5923
#            1       0.98      0.98      0.98      6742
#            2       0.97      0.96      0.97      5958
#            3       0.97      0.95      0.96      6131
#            4       0.98      0.96      0.97      5842
#            5       0.97      0.95      0.96      5421
#            6       0.95      0.99      0.97      5918
#            7       0.95      0.98      0.96      6265
#            8       0.97      0.95      0.96      5851
#            9       0.95      0.96      0.95      5949
#
#     accuracy                           0.97     60000
#    macro avg       0.97      0.97      0.97     60000
# weighted avg       0.97      0.97      0.97     60000
#
#
# ---------- Evaluation on Test Data -----------
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       980
#            1       0.98      0.98      0.98      1135
#            2       0.96      0.96      0.96      1032
#            3       0.96      0.96      0.96      1010
#            4       0.97      0.95      0.96       982
#            5       0.97      0.94      0.95       892
#            6       0.94      0.98      0.96       958
#            7       0.93      0.96      0.95      1028
#            8       0.97      0.93      0.95       974
#            9       0.94      0.94      0.94      1009
#
#     accuracy                           0.96     10000
#    macro avg       0.96      0.96      0.96     10000
# weighted avg       0.96      0.96      0.96     10000
# Training Accuracy: 0.9675
# Testing Accuracy: 0.9606

# %%
# Load required packages
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras import Input
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report

# Load Fashion MNIST data
(X_train, y_train), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Print shapes
print("Shape of X_train: ", X_train.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of y_test: ", y_test.shape)

# Display images of the first 10 items in the training set and their true labels
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

fig, axs = plt.subplots(2, 5, sharey=False, tight_layout=True, figsize=(12, 6), facecolor='white')
n = 0
for i in range(2):
    for j in range(5):
        axs[i, j].imshow(X_train[n], cmap='gray')
        axs[i, j].set(title=class_names[y_train[n]])
        axs[i, j].axis('off')
        n += 1
plt.show()

# Reshape and normalize (divide by 255) input data
X_train = X_train.reshape(60000, 784).astype("float32") / 255
X_test = X_test.reshape(10000, 784).astype("float32") / 255

# Print new shapes
print("New shape of X_train: ", X_train.shape)
print("New shape of X_test: ", X_test.shape)

# Design the Deep Feedforward Neural Network (DFF) architecture
model = Sequential(name="DFF-FashionMNIST")
model.add(Input(shape=(784,), name='Input-Layer'))
model.add(Dense(128, activation='relu', name='Hidden-Layer-1', kernel_initializer='HeNormal'))
model.add(Dense(64, activation='relu', name='Hidden-Layer-2', kernel_initializer='HeNormal'))
model.add(Dense(32, activation='relu', name='Hidden-Layer-3', kernel_initializer='HeNormal'))
model.add(Dense(10, activation='softmax', name='Output-Layer'))

# Compile the model
model.compile(optimizer='adam', loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, batch_size=10, epochs=5, verbose=1, validation_split=0.2, shuffle=True)

# Make predictions
pred_labels_tr = np.array(tf.math.argmax(model.predict(X_train), axis=1))
pred_labels_te = np.array(tf.math.argmax(model.predict(X_test), axis=1))

# Model Summary
print("\nModel Summary:")
model.summary()

# Evaluation on Training Data
print("\n---------- Evaluation on Training Data -----------")
print(classification_report(y_train, pred_labels_tr, target_names=class_names))

# Evaluation on Test Data
print("\n---------- Evaluation on Test Data -----------")
print(classification_report(y_test, pred_labels_te, target_names=class_names))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Shape of X_train:  (60000, 28, 28)
# Shape of y_train:  (60000,)
# Shape of X_test:  (10000, 28, 28)
# Shape of y_test:  (10000,)
# New shape of X_train:  (60000, 784)
# New shape of X_test:  (10000, 784)
# Epoch 1/5
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 26s 5ms/step - accuracy: 0.7638 - loss: 0.6691 - val_accuracy: 0.8512 - val_loss: 0.4148
# Epoch 2/5
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 25s 5ms/step - accuracy: 0.8537 - loss: 0.3996 - val_accuracy: 0.8628 - val_loss: 0.3784
# Epoch 3/5
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 28s 6ms/step - accuracy: 0.8726 - loss: 0.3465 - val_accuracy: 0.8698 - val_loss: 0.3567
# Epoch 4/5
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.8804 - loss: 0.3251 - val_accuracy: 0.8715 - val_loss: 0.3536
# Epoch 5/5
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step - accuracy: 0.8863 - loss: 0.3035 - val_accuracy: 0.8728 - val_loss: 0.3558
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# Model Summary:
# Model: "DFF-FashionMNIST"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden-Layer-1 (Dense)          │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-3 (Dense)          │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output-Layer (Dense)            │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 333,440 (1.27 MB)
#  Trainable params: 111,146 (434.16 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 222,294 (868.34 KB)
# ---------- Evaluation on Training Data -----------
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.85      0.82      0.84      6000
#      Trouser       0.99      0.98      0.98      6000
#     Pullover       0.87      0.71      0.78      6000
#        Dress       0.84      0.93      0.88      6000
#         Coat       0.70      0.92      0.79      6000
#       Sandal       0.96      0.96      0.96      6000
#        Shirt       0.80      0.64      0.71      6000
#      Sneaker       0.96      0.94      0.95      6000
#          Bag       0.98      0.97      0.98      6000
#   Ankle boot       0.95      0.97      0.96      6000
#
#     accuracy                           0.88     60000
#    macro avg       0.89      0.88      0.88     60000
# weighted avg       0.89      0.88      0.88     60000
#
#
# ---------- Evaluation on Test Data -----------
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.84      0.79      0.81      1000
#      Trouser       0.99      0.96      0.98      1000
#     Pullover       0.84      0.68      0.75      1000
#        Dress       0.81      0.92      0.86      1000
#         Coat       0.68      0.89      0.77      1000
#       Sandal       0.96      0.94      0.95      1000
#        Shirt       0.76      0.61      0.67      1000
#      Sneaker       0.94      0.93      0.94      1000
#          Bag       0.97      0.97      0.97      1000
#   Ankle boot       0.93      0.97      0.95      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000

# %%
# Load required packages
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras import Input
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report

# Load Fashion MNIST data
(X_train, y_train), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Print shapes
print("Shape of X_train: ", X_train.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of y_test: ", y_test.shape)

# Display images of the first 10 items in the training set and their true labels
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

fig, axs = plt.subplots(2, 5, sharey=False, tight_layout=True, figsize=(12, 6), facecolor='white')
n = 0
for i in range(2):
    for j in range(5):
        axs[i, j].imshow(X_train[n], cmap='gray')
        axs[i, j].set(title=class_names[y_train[n]])
        axs[i, j].axis('off')
        n += 1
plt.show()

# Reshape and normalize (divide by 255) input data
X_train = X_train.reshape(60000, 784).astype("float32") / 255
X_test = X_test.reshape(10000, 784).astype("float32") / 255

# Print new shapes
print("New shape of X_train: ", X_train.shape)
print("New shape of X_test: ", X_test.shape)

# Design the Deep Feedforward Neural Network (DFF) architecture
model = Sequential(name="DFF-FashionMNIST")
model.add(Input(shape=(784,), name='Input-Layer'))
model.add(Dense(128, activation='relu', name='Hidden-Layer-1', kernel_initializer='HeNormal'))
model.add(Dense(64, activation='relu', name='Hidden-Layer-2', kernel_initializer='HeNormal'))
model.add(Dense(32, activation='relu', name='Hidden-Layer-3', kernel_initializer='HeNormal'))
model.add(Dense(10, activation='softmax', name='Output-Layer'))

# Compile the model
model.compile(optimizer='adam', loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, batch_size=10, epochs=10, verbose=1, validation_split=0.2, shuffle=True)

# Make predictions
pred_labels_tr = np.array(tf.math.argmax(model.predict(X_train), axis=1))
pred_labels_te = np.array(tf.math.argmax(model.predict(X_test), axis=1))

# Model Summary
print("\nModel Summary:")
model.summary()

# Evaluation on Training Data
print("\n---------- Evaluation on Training Data -----------")
print(classification_report(y_train, pred_labels_tr, target_names=class_names))

# Evaluation on Test Data
print("\n---------- Evaluation on Test Data -----------")
print(classification_report(y_test, pred_labels_te, target_names=class_names))
# Out:
# Shape of X_train:  (60000, 28, 28)
# Shape of y_train:  (60000,)
# Shape of X_test:  (10000, 28, 28)
# Shape of y_test:  (10000,)
# New shape of X_train:  (60000, 784)
# New shape of X_test:  (10000, 784)
# Epoch 1/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 26s 5ms/step - accuracy: 0.7719 - loss: 0.6453 - val_accuracy: 0.8550 - val_loss: 0.4021
# Epoch 2/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.8543 - loss: 0.3967 - val_accuracy: 0.8623 - val_loss: 0.3754
# Epoch 3/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 39s 5ms/step - accuracy: 0.8695 - loss: 0.3538 - val_accuracy: 0.8748 - val_loss: 0.3448
# Epoch 4/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.8789 - loss: 0.3259 - val_accuracy: 0.8742 - val_loss: 0.3563
# Epoch 5/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 25s 5ms/step - accuracy: 0.8862 - loss: 0.3048 - val_accuracy: 0.8712 - val_loss: 0.3598
# Epoch 6/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.8888 - loss: 0.2983 - val_accuracy: 0.8780 - val_loss: 0.3515
# Epoch 7/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 25s 5ms/step - accuracy: 0.8958 - loss: 0.2747 - val_accuracy: 0.8844 - val_loss: 0.3404
# Epoch 8/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.9010 - loss: 0.2651 - val_accuracy: 0.8824 - val_loss: 0.3380
# Epoch 9/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 25s 5ms/step - accuracy: 0.9043 - loss: 0.2597 - val_accuracy: 0.8873 - val_loss: 0.3276
# Epoch 10/10
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.9076 - loss: 0.2514 - val_accuracy: 0.8852 - val_loss: 0.3231
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# Model Summary:
# Model: "DFF-FashionMNIST"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden-Layer-1 (Dense)          │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-3 (Dense)          │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output-Layer (Dense)            │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 333,440 (1.27 MB)
#  Trainable params: 111,146 (434.16 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 222,294 (868.34 KB)
# ---------- Evaluation on Training Data -----------
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.87      0.84      0.86      6000
#      Trouser       0.99      0.98      0.99      6000
#     Pullover       0.82      0.85      0.84      6000
#        Dress       0.89      0.95      0.92      6000
#         Coat       0.87      0.78      0.82      6000
#       Sandal       0.98      0.98      0.98      6000
#        Shirt       0.73      0.76      0.75      6000
#      Sneaker       0.96      0.97      0.97      6000
#          Bag       0.98      0.99      0.98      6000
#   Ankle boot       0.98      0.96      0.97      6000
#
#     accuracy                           0.91     60000
#    macro avg       0.91      0.91      0.91     60000
# weighted avg       0.91      0.91      0.91     60000
#
#
# ---------- Evaluation on Test Data -----------
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.85      0.80      0.82      1000
#      Trouser       0.99      0.97      0.98      1000
#     Pullover       0.78      0.80      0.79      1000
#        Dress       0.84      0.91      0.88      1000
#         Coat       0.82      0.74      0.78      1000
#       Sandal       0.97      0.96      0.97      1000
#        Shirt       0.67      0.71      0.69      1000
#      Sneaker       0.93      0.97      0.95      1000
#          Bag       0.97      0.97      0.97      1000
#   Ankle boot       0.97      0.95      0.96      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000

# %%
# Load required packages
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras import Input
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report

# Load Fashion MNIST data
(X_train, y_train), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Print shapes
print("Shape of X_train: ", X_train.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of y_test: ", y_test.shape)

# Display images of the first 10 items in the training set and their true labels
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

fig, axs = plt.subplots(2, 5, sharey=False, tight_layout=True, figsize=(12, 6), facecolor='white')
n = 0
for i in range(2):
    for j in range(5):
        axs[i, j].imshow(X_train[n], cmap='gray')
        axs[i, j].set(title=class_names[y_train[n]])
        axs[i, j].axis('off')
        n += 1
plt.show()

# Reshape and normalize (divide by 255) input data
X_train = X_train.reshape(60000, 784).astype("float32") / 255
X_test = X_test.reshape(10000, 784).astype("float32") / 255

# Print new shapes
print("New shape of X_train: ", X_train.shape)
print("New shape of X_test: ", X_test.shape)

# Design the Deep Feedforward Neural Network (DFF) architecture
model = Sequential(name="DFF-FashionMNIST")
model.add(Input(shape=(784,), name='Input-Layer'))
model.add(Dense(128, activation='relu', name='Hidden-Layer-1', kernel_initializer='HeNormal'))
model.add(Dense(64, activation='relu', name='Hidden-Layer-2', kernel_initializer='HeNormal'))
model.add(Dense(32, activation='relu', name='Hidden-Layer-3', kernel_initializer='HeNormal'))
model.add(Dense(10, activation='softmax', name='Output-Layer'))

# Compile the model
model.compile(optimizer='adam', loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, batch_size=10, epochs=15, verbose=1, validation_split=0.2, shuffle=True)

# Make predictions
pred_labels_tr = np.array(tf.math.argmax(model.predict(X_train), axis=1))
pred_labels_te = np.array(tf.math.argmax(model.predict(X_test), axis=1))

# Model Summary
print("\nModel Summary:")
model.summary()

# Evaluation on Training Data
print("\n---------- Evaluation on Training Data -----------")
print(classification_report(y_train, pred_labels_tr, target_names=class_names))

# Evaluation on Test Data
print("\n---------- Evaluation on Test Data -----------")
print(classification_report(y_test, pred_labels_te, target_names=class_names))
# Out:
# Shape of X_train:  (60000, 28, 28)
# Shape of y_train:  (60000,)
# Shape of X_test:  (10000, 28, 28)
# Shape of y_test:  (10000,)
# New shape of X_train:  (60000, 784)
# New shape of X_test:  (10000, 784)
# Epoch 1/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 27s 5ms/step - accuracy: 0.7649 - loss: 0.6540 - val_accuracy: 0.8283 - val_loss: 0.4667
# Epoch 2/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.8583 - loss: 0.3898 - val_accuracy: 0.8630 - val_loss: 0.3705
# Epoch 3/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.8702 - loss: 0.3513 - val_accuracy: 0.8699 - val_loss: 0.3524
# Epoch 4/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 26s 5ms/step - accuracy: 0.8803 - loss: 0.3234 - val_accuracy: 0.8773 - val_loss: 0.3469
# Epoch 5/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 28s 6ms/step - accuracy: 0.8857 - loss: 0.3076 - val_accuracy: 0.8765 - val_loss: 0.3519
# Epoch 6/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.8898 - loss: 0.2939 - val_accuracy: 0.8539 - val_loss: 0.4192
# Epoch 7/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.8965 - loss: 0.2834 - val_accuracy: 0.8806 - val_loss: 0.3427
# Epoch 8/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 32s 7ms/step - accuracy: 0.9002 - loss: 0.2687 - val_accuracy: 0.8805 - val_loss: 0.3521
# Epoch 9/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 34s 7ms/step - accuracy: 0.9012 - loss: 0.2662 - val_accuracy: 0.8800 - val_loss: 0.3472
# Epoch 10/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 30s 6ms/step - accuracy: 0.9042 - loss: 0.2531 - val_accuracy: 0.8867 - val_loss: 0.3299
# Epoch 11/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 39s 6ms/step - accuracy: 0.9089 - loss: 0.2432 - val_accuracy: 0.8832 - val_loss: 0.3439
# Epoch 12/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 26s 5ms/step - accuracy: 0.9103 - loss: 0.2411 - val_accuracy: 0.8865 - val_loss: 0.3384
# Epoch 13/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 25s 5ms/step - accuracy: 0.9086 - loss: 0.2425 - val_accuracy: 0.8898 - val_loss: 0.3278
# Epoch 14/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 25s 5ms/step - accuracy: 0.9139 - loss: 0.2266 - val_accuracy: 0.8842 - val_loss: 0.3509
# Epoch 15/15
# 4800/4800 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.9158 - loss: 0.2209 - val_accuracy: 0.8838 - val_loss: 0.3475
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# Model Summary:
# Model: "DFF-FashionMNIST"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden-Layer-1 (Dense)          │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-3 (Dense)          │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output-Layer (Dense)            │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 333,440 (1.27 MB)
#  Trainable params: 111,146 (434.16 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 222,294 (868.34 KB)
# ---------- Evaluation on Training Data -----------
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.89      0.85      0.87      6000
#      Trouser       0.98      0.99      0.99      6000
#     Pullover       0.86      0.84      0.85      6000
#        Dress       0.91      0.94      0.93      6000
#         Coat       0.81      0.88      0.84      6000
#       Sandal       1.00      0.95      0.98      6000
#        Shirt       0.80      0.74      0.77      6000
#      Sneaker       0.95      0.98      0.96      6000
#          Bag       0.98      0.99      0.99      6000
#   Ankle boot       0.97      0.97      0.97      6000
#
#     accuracy                           0.91     60000
#    macro avg       0.91      0.91      0.91     60000
# weighted avg       0.91      0.91      0.91     60000
#
#
# ---------- Evaluation on Test Data -----------
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.86      0.80      0.83      1000
#      Trouser       0.97      0.97      0.97      1000
#     Pullover       0.79      0.80      0.79      1000
#        Dress       0.88      0.89      0.88      1000
#         Coat       0.77      0.83      0.80      1000
#       Sandal       0.99      0.92      0.95      1000
#        Shirt       0.71      0.66      0.69      1000
#      Sneaker       0.91      0.97      0.94      1000
#          Bag       0.95      0.97      0.96      1000
#   Ankle boot       0.95      0.96      0.96      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000

# %%
from sklearn.metrics import classification_report
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Generate classification reports as dictionaries
report_train = classification_report(y_train, pred_labels_tr, target_names=class_names, output_dict=True)
report_test = classification_report(y_test, pred_labels_te, target_names=class_names, output_dict=True)

# Convert to DataFrames
df_train = pd.DataFrame(report_train).transpose()
df_test = pd.DataFrame(report_test).transpose()

# Select only the main average metrics
metrics = ['precision', 'recall', 'f1-score']
labels = ['Training', 'Testing']

# Extract macro average scores
train_scores = df_train.loc['macro avg', metrics]
test_scores = df_test.loc['macro avg', metrics]

# Plotting
x = np.arange(len(metrics))  # label locations
width = 0.35  # width of the bars

fig, ax = plt.subplots(figsize=(8, 6))
rects1 = ax.bar(x - width/2, train_scores, width, label='Training', color='skyblue')
rects2 = ax.bar(x + width/2, test_scores, width, label='Testing', color='salmon')

# Add labels and formatting
ax.set_ylabel('Scores')
ax.set_title('Macro Average Performance Comparison (Fashion MNIST)')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Add value labels on top of bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.ylim(0, 1.1)  # Set upper limit slightly above 1
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Load required packages
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras import Input
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report
import pandas as pd

# Load CIFAR-10 data
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()

# Flatten label arrays
y_train = y_train.flatten()
y_test = y_test.flatten()

# Print shapes
print("Shape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_test:", y_test.shape)

# Class names for CIFAR-10
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer',
               'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# Display first 10 CIFAR-10 images
fig, axs = plt.subplots(2, 5, figsize=(12, 6), facecolor='white')
n = 0
for i in range(2):
    for j in range(5):
        axs[i, j].imshow(X_train[n])
        axs[i, j].set(title=class_names[y_train[n]])
        axs[i, j].axis('off')
        n += 1
plt.show()

# Reshape and normalize input data (flatten 32x32x3 to 3072 and normalize)
X_train = X_train.reshape(50000, 3072).astype("float32") / 255
X_test = X_test.reshape(10000, 3072).astype("float32") / 255

# Print new shapes
print("New shape of X_train:", X_train.shape)
print("New shape of X_test:", X_test.shape)

# Define the DFF model
model = Sequential(name="DFF-CIFAR10")
model.add(Input(shape=(3072,), name='Input-Layer'))
model.add(Dense(512, activation='relu', name='Hidden-Layer-1', kernel_initializer='HeNormal'))
model.add(Dense(256, activation='relu', name='Hidden-Layer-2', kernel_initializer='HeNormal'))
model.add(Dense(128, activation='relu', name='Hidden-Layer-3', kernel_initializer='HeNormal'))
model.add(Dense(10, activation='softmax', name='Output-Layer'))

# Compile the model
model.compile(optimizer='adam', loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, batch_size=32, epochs=5, verbose=1, validation_split=0.2, shuffle=True)

# Predict labels
pred_labels_tr = np.array(tf.math.argmax(model.predict(X_train), axis=1))
pred_labels_te = np.array(tf.math.argmax(model.predict(X_test), axis=1))

# Model Summary
print("\nModel Summary:")
model.summary()

# Evaluation
print("\n---------- Evaluation on Training Data -----------")
report_train = classification_report(y_train, pred_labels_tr, target_names=class_names, output_dict=True)
print(classification_report(y_train, pred_labels_tr, target_names=class_names))

print("\n---------- Evaluation on Test Data -----------")
report_test = classification_report(y_test, pred_labels_te, target_names=class_names, output_dict=True)
print(classification_report(y_test, pred_labels_te, target_names=class_names))

# Plot Macro Average Comparison
df_train = pd.DataFrame(report_train).transpose()
df_test = pd.DataFrame(report_test).transpose()

metrics = ['precision', 'recall', 'f1-score']
train_scores = df_train.loc['macro avg', metrics]
test_scores = df_test.loc['macro avg', metrics]

x = np.arange(len(metrics))
width = 0.35

fig, ax = plt.subplots(figsize=(8, 6))
rects1 = ax.bar(x - width/2, train_scores, width, label='Training', color='skyblue')
rects2 = ax.bar(x + width/2, test_scores, width, label='Testing', color='salmon')

ax.set_ylabel('Scores')
ax.set_title('Macro Average Performance Comparison (CIFAR-10)')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.ylim(0, 1.1)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Shape of X_train: (50000, 32, 32, 3)
# Shape of y_train: (50000,)
# Shape of X_test: (10000, 32, 32, 3)
# Shape of y_test: (10000,)
# New shape of X_train: (50000, 3072)
# New shape of X_test: (10000, 3072)
# Epoch 1/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 48s 37ms/step - accuracy: 0.2642 - loss: 2.0650 - val_accuracy: 0.3654 - val_loss: 1.7576
# Epoch 2/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 33ms/step - accuracy: 0.3843 - loss: 1.7074 - val_accuracy: 0.3945 - val_loss: 1.6929
# Epoch 3/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 79s 31ms/step - accuracy: 0.4126 - loss: 1.6260 - val_accuracy: 0.4116 - val_loss: 1.6392
# Epoch 4/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 33ms/step - accuracy: 0.4388 - loss: 1.5671 - val_accuracy: 0.4154 - val_loss: 1.6214
# Epoch 5/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 33ms/step - accuracy: 0.4552 - loss: 1.5159 - val_accuracy: 0.4125 - val_loss: 1.6766
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 64s 41ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
#
# Model Summary:
# Model: "DFF-CIFAR10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden-Layer-1 (Dense)          │ (None, 512)            │     1,573,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-2 (Dense)          │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-3 (Dense)          │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output-Layer (Dense)            │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,216,672 (19.90 MB)
#  Trainable params: 1,738,890 (6.63 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 3,477,782 (13.27 MB)
# ---------- Evaluation on Training Data -----------
#               precision    recall  f1-score   support
#
#     Airplane       0.53      0.48      0.51      5000
#   Automobile       0.43      0.74      0.54      5000
#         Bird       0.36      0.28      0.32      5000
#          Cat       0.43      0.03      0.06      5000
#         Deer       0.49      0.19      0.27      5000
#          Dog       0.34      0.45      0.39      5000
#         Frog       0.57      0.33      0.42      5000
#        Horse       0.30      0.77      0.43      5000
#         Ship       0.60      0.57      0.59      5000
#        Truck       0.56      0.41      0.47      5000
#
#     accuracy                           0.43     50000
#    macro avg       0.46      0.43      0.40     50000
# weighted avg       0.46      0.43      0.40     50000
#
#
# ---------- Evaluation on Test Data -----------
#               precision    recall  f1-score   support
#
#     Airplane       0.54      0.50      0.52      1000
#   Automobile       0.44      0.74      0.55      1000
#         Bird       0.34      0.28      0.31      1000
#          Cat       0.27      0.01      0.03      1000
#         Deer       0.48      0.20      0.28      1000
#          Dog       0.33      0.42      0.37      1000
#         Frog       0.54      0.33      0.41      1000
#        Horse       0.29      0.75      0.42      1000
#         Ship       0.56      0.55      0.56      1000
#        Truck       0.57      0.39      0.46      1000
#
#     accuracy                           0.42     10000
#    macro avg       0.44      0.42      0.39     10000
# weighted avg       0.44      0.42      0.39     10000

# %%
# Load required packages
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras import Input
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report
import pandas as pd

# Load CIFAR-10 data
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()

# Flatten label arrays
y_train = y_train.flatten()
y_test = y_test.flatten()

# Print shapes
print("Shape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_test:", y_test.shape)

# Class names for CIFAR-10
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer',
               'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# Display first 10 CIFAR-10 images
fig, axs = plt.subplots(2, 5, figsize=(12, 6), facecolor='white')
n = 0
for i in range(2):
    for j in range(5):
        axs[i, j].imshow(X_train[n])
        axs[i, j].set(title=class_names[y_train[n]])
        axs[i, j].axis('off')
        n += 1
plt.show()

# Reshape and normalize input data (flatten 32x32x3 to 3072 and normalize)
X_train = X_train.reshape(50000, 3072).astype("float32") / 255
X_test = X_test.reshape(10000, 3072).astype("float32") / 255

# Print new shapes
print("New shape of X_train:", X_train.shape)
print("New shape of X_test:", X_test.shape)

# Define the DFF model
model = Sequential(name="DFF-CIFAR10")
model.add(Input(shape=(3072,), name='Input-Layer'))
model.add(Dense(512, activation='relu', name='Hidden-Layer-1', kernel_initializer='HeNormal'))
model.add(Dense(256, activation='relu', name='Hidden-Layer-2', kernel_initializer='HeNormal'))
model.add(Dense(128, activation='relu', name='Hidden-Layer-3', kernel_initializer='HeNormal'))
model.add(Dense(10, activation='softmax', name='Output-Layer'))

# Compile the model
model.compile(optimizer='adam', loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, batch_size=32, epochs=10, verbose=1, validation_split=0.2, shuffle=True)

# Predict labels
pred_labels_tr = np.array(tf.math.argmax(model.predict(X_train), axis=1))
pred_labels_te = np.array(tf.math.argmax(model.predict(X_test), axis=1))

# Model Summary
print("\nModel Summary:")
model.summary()

# Evaluation
print("\n---------- Evaluation on Training Data -----------")
report_train = classification_report(y_train, pred_labels_tr, target_names=class_names, output_dict=True)
print(classification_report(y_train, pred_labels_tr, target_names=class_names))

print("\n---------- Evaluation on Test Data -----------")
report_test = classification_report(y_test, pred_labels_te, target_names=class_names, output_dict=True)
print(classification_report(y_test, pred_labels_te, target_names=class_names))

# Plot Macro Average Comparison
df_train = pd.DataFrame(report_train).transpose()
df_test = pd.DataFrame(report_test).transpose()

metrics = ['precision', 'recall', 'f1-score']
train_scores = df_train.loc['macro avg', metrics]
test_scores = df_test.loc['macro avg', metrics]

x = np.arange(len(metrics))
width = 0.35

fig, ax = plt.subplots(figsize=(8, 6))
rects1 = ax.bar(x - width/2, train_scores, width, label='Training', color='skyblue')
rects2 = ax.bar(x + width/2, test_scores, width, label='Testing', color='salmon')

ax.set_ylabel('Scores')
ax.set_title('Macro Average Performance Comparison (CIFAR-10)')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.ylim(0, 1.1)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Shape of X_train: (50000, 32, 32, 3)
# Shape of y_train: (50000,)
# Shape of X_test: (10000, 32, 32, 3)
# Shape of y_test: (10000,)
# New shape of X_train: (50000, 3072)
# New shape of X_test: (10000, 3072)
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 48s 38ms/step - accuracy: 0.2543 - loss: 2.0681 - val_accuracy: 0.3626 - val_loss: 1.7756
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 34ms/step - accuracy: 0.3776 - loss: 1.7269 - val_accuracy: 0.4077 - val_loss: 1.6656
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 35ms/step - accuracy: 0.4172 - loss: 1.6214 - val_accuracy: 0.4148 - val_loss: 1.6275
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 33ms/step - accuracy: 0.4403 - loss: 1.5590 - val_accuracy: 0.4320 - val_loss: 1.5832
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 35ms/step - accuracy: 0.4518 - loss: 1.5268 - val_accuracy: 0.4256 - val_loss: 1.6032
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 31ms/step - accuracy: 0.4657 - loss: 1.4935 - val_accuracy: 0.4555 - val_loss: 1.5323
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.4734 - loss: 1.4582 - val_accuracy: 0.4683 - val_loss: 1.5077
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 79s 31ms/step - accuracy: 0.4861 - loss: 1.4280 - val_accuracy: 0.4655 - val_loss: 1.5014
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 39s 32ms/step - accuracy: 0.4922 - loss: 1.4084 - val_accuracy: 0.4426 - val_loss: 1.5644
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 39s 31ms/step - accuracy: 0.5088 - loss: 1.3823 - val_accuracy: 0.4746 - val_loss: 1.4850
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
#
# Model Summary:
# Model: "DFF-CIFAR10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden-Layer-1 (Dense)          │ (None, 512)            │     1,573,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-2 (Dense)          │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-3 (Dense)          │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output-Layer (Dense)            │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,216,672 (19.90 MB)
#  Trainable params: 1,738,890 (6.63 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 3,477,782 (13.27 MB)
# ---------- Evaluation on Training Data -----------
#               precision    recall  f1-score   support
#
#     Airplane       0.60      0.51      0.55      5000
#   Automobile       0.70      0.55      0.62      5000
#         Bird       0.45      0.28      0.34      5000
#          Cat       0.36      0.40      0.38      5000
#         Deer       0.52      0.35      0.42      5000
#          Dog       0.44      0.42      0.43      5000
#         Frog       0.45      0.65      0.54      5000
#        Horse       0.58      0.59      0.58      5000
#         Ship       0.64      0.64      0.64      5000
#        Truck       0.46      0.72      0.57      5000
#
#     accuracy                           0.51     50000
#    macro avg       0.52      0.51      0.51     50000
# weighted avg       0.52      0.51      0.51     50000
#
#
# ---------- Evaluation on Test Data -----------
#               precision    recall  f1-score   support
#
#     Airplane       0.59      0.50      0.54      1000
#   Automobile       0.66      0.49      0.56      1000
#         Bird       0.42      0.24      0.31      1000
#          Cat       0.32      0.36      0.34      1000
#         Deer       0.48      0.31      0.38      1000
#          Dog       0.41      0.39      0.40      1000
#         Frog       0.43      0.66      0.52      1000
#        Horse       0.55      0.54      0.54      1000
#         Ship       0.59      0.61      0.60      1000
#        Truck       0.44      0.68      0.53      1000
#
#     accuracy                           0.48     10000
#    macro avg       0.49      0.48      0.47     10000
# weighted avg       0.49      0.48      0.47     10000

# %%
# Load required packages
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras import Input
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report
import pandas as pd

# Load CIFAR-10 data
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()

# Flatten label arrays
y_train = y_train.flatten()
y_test = y_test.flatten()

# Print shapes
print("Shape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_test:", y_test.shape)

# Class names for CIFAR-10
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer',
               'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# Display first 10 CIFAR-10 images
fig, axs = plt.subplots(2, 5, figsize=(12, 6), facecolor='white')
n = 0
for i in range(2):
    for j in range(5):
        axs[i, j].imshow(X_train[n])
        axs[i, j].set(title=class_names[y_train[n]])
        axs[i, j].axis('off')
        n += 1
plt.show()

# Reshape and normalize input data (flatten 32x32x3 to 3072 and normalize)
X_train = X_train.reshape(50000, 3072).astype("float32") / 255
X_test = X_test.reshape(10000, 3072).astype("float32") / 255

# Print new shapes
print("New shape of X_train:", X_train.shape)
print("New shape of X_test:", X_test.shape)

# Define the DFF model
model = Sequential(name="DFF-CIFAR10")
model.add(Input(shape=(3072,), name='Input-Layer'))
model.add(Dense(512, activation='relu', name='Hidden-Layer-1', kernel_initializer='HeNormal'))
model.add(Dense(256, activation='relu', name='Hidden-Layer-2', kernel_initializer='HeNormal'))
model.add(Dense(128, activation='relu', name='Hidden-Layer-3', kernel_initializer='HeNormal'))
model.add(Dense(10, activation='softmax', name='Output-Layer'))

# Compile the model
model.compile(optimizer='adam', loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, batch_size=32, epochs=5, verbose=1, validation_split=0.2, shuffle=True)

# Predict labels
pred_labels_tr = np.array(tf.math.argmax(model.predict(X_train), axis=1))
pred_labels_te = np.array(tf.math.argmax(model.predict(X_test), axis=1))

# Model Summary
print("\nModel Summary:")
model.summary()

# Evaluation
print("\n---------- Evaluation on Training Data -----------")
report_train = classification_report(y_train, pred_labels_tr, target_names=class_names, output_dict=True)
print(classification_report(y_train, pred_labels_tr, target_names=class_names))

print("\n---------- Evaluation on Test Data -----------")
report_test = classification_report(y_test, pred_labels_te, target_names=class_names, output_dict=True)
print(classification_report(y_test, pred_labels_te, target_names=class_names))

# Plot Macro Average Comparison
df_train = pd.DataFrame(report_train).transpose()
df_test = pd.DataFrame(report_test).transpose()

metrics = ['precision', 'recall', 'f1-score']
train_scores = df_train.loc['macro avg', metrics]
test_scores = df_test.loc['macro avg', metrics]

x = np.arange(len(metrics))
width = 0.35

fig, ax = plt.subplots(figsize=(8, 6))
rects1 = ax.bar(x - width/2, train_scores, width, label='Training', color='skyblue')
rects2 = ax.bar(x + width/2, test_scores, width, label='Testing', color='salmon')

ax.set_ylabel('Scores')
ax.set_title('Macro Average Performance Comparison (CIFAR-10)')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.ylim(0, 1.1)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Shape of X_train: (50000, 32, 32, 3)
# Shape of y_train: (50000,)
# Shape of X_test: (10000, 32, 32, 3)
# Shape of y_test: (10000,)
# New shape of X_train: (50000, 3072)
# New shape of X_test: (10000, 3072)
# Epoch 1/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 34ms/step - accuracy: 0.2647 - loss: 2.0495 - val_accuracy: 0.3795 - val_loss: 1.7308
# Epoch 2/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 40s 32ms/step - accuracy: 0.3835 - loss: 1.7156 - val_accuracy: 0.4055 - val_loss: 1.6587
# Epoch 3/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 35ms/step - accuracy: 0.4158 - loss: 1.6272 - val_accuracy: 0.4349 - val_loss: 1.5801
# Epoch 4/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 81s 34ms/step - accuracy: 0.4400 - loss: 1.5614 - val_accuracy: 0.4269 - val_loss: 1.6034
# Epoch 5/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 34ms/step - accuracy: 0.4554 - loss: 1.5231 - val_accuracy: 0.4315 - val_loss: 1.5963
# Epoch 6/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 34ms/step - accuracy: 0.4645 - loss: 1.4905 - val_accuracy: 0.4505 - val_loss: 1.5368
# Epoch 7/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 79s 31ms/step - accuracy: 0.4785 - loss: 1.4499 - val_accuracy: 0.4591 - val_loss: 1.5227
# Epoch 8/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.4916 - loss: 1.4135 - val_accuracy: 0.4362 - val_loss: 1.5831
# Epoch 9/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 31ms/step - accuracy: 0.4928 - loss: 1.3954 - val_accuracy: 0.4565 - val_loss: 1.5253
# Epoch 10/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.5113 - loss: 1.3675 - val_accuracy: 0.4728 - val_loss: 1.5006
# Epoch 11/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 80s 32ms/step - accuracy: 0.5117 - loss: 1.3604 - val_accuracy: 0.4730 - val_loss: 1.4864
# Epoch 12/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 40s 31ms/step - accuracy: 0.5280 - loss: 1.3150 - val_accuracy: 0.4673 - val_loss: 1.5254
# Epoch 13/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 34ms/step - accuracy: 0.5272 - loss: 1.3019 - val_accuracy: 0.4666 - val_loss: 1.5502
# Epoch 14/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 40s 32ms/step - accuracy: 0.5393 - loss: 1.2858 - val_accuracy: 0.4844 - val_loss: 1.4852
# Epoch 15/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 38s 30ms/step - accuracy: 0.5472 - loss: 1.2560 - val_accuracy: 0.4791 - val_loss: 1.5221
# Epoch 16/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.5500 - loss: 1.2471 - val_accuracy: 0.4895 - val_loss: 1.4811
# Epoch 17/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 80s 31ms/step - accuracy: 0.5661 - loss: 1.2087 - val_accuracy: 0.4738 - val_loss: 1.5259
# Epoch 18/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 32ms/step - accuracy: 0.5647 - loss: 1.2131 - val_accuracy: 0.4829 - val_loss: 1.5153
# Epoch 19/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 40s 31ms/step - accuracy: 0.5734 - loss: 1.1833 - val_accuracy: 0.4849 - val_loss: 1.5137
# Epoch 20/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 34ms/step - accuracy: 0.5786 - loss: 1.1750 - val_accuracy: 0.4867 - val_loss: 1.5029
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
#
# Model Summary:
# Model: "DFF-CIFAR10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden-Layer-1 (Dense)          │ (None, 512)            │     1,573,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-2 (Dense)          │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-3 (Dense)          │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output-Layer (Dense)            │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,216,672 (19.90 MB)
#  Trainable params: 1,738,890 (6.63 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 3,477,782 (13.27 MB)
# ---------- Evaluation on Training Data -----------
#               precision    recall  f1-score   support
#
#     Airplane       0.67      0.55      0.60      5000
#   Automobile       0.76      0.61      0.68      5000
#         Bird       0.52      0.41      0.45      5000
#          Cat       0.49      0.31      0.38      5000
#         Deer       0.46      0.58      0.51      5000
#          Dog       0.51      0.51      0.51      5000
#         Frog       0.57      0.65      0.61      5000
#        Horse       0.60      0.69      0.64      5000
#         Ship       0.63      0.77      0.69      5000
#        Truck       0.59      0.71      0.64      5000
#
#     accuracy                           0.58     50000
#    macro avg       0.58      0.58      0.57     50000
# weighted avg       0.58      0.58      0.57     50000
#
#
# ---------- Evaluation on Test Data -----------
#               precision    recall  f1-score   support
#
#     Airplane       0.61      0.49      0.55      1000
#   Automobile       0.66      0.52      0.58      1000
#         Bird       0.38      0.29      0.33      1000
#          Cat       0.36      0.23      0.28      1000
#         Deer       0.39      0.48      0.43      1000
#          Dog       0.40      0.40      0.40      1000
#         Frog       0.49      0.59      0.53      1000
#        Horse       0.50      0.57      0.53      1000
#         Ship       0.57      0.71      0.63      1000
#        Truck       0.51      0.60      0.55      1000
#
#     accuracy                           0.49     10000
#    macro avg       0.49      0.49      0.48     10000
# weighted avg       0.49      0.49      0.48     10000
